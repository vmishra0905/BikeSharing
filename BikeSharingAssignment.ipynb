# %%
## supress warings
import warnings
warnings.filterwarnings('ignore')

# %%
## import numpy and panda library
import numpy as np
import pandas as pd

# %%
##loading csv data
bike_share=pd.read_csv('day.csv')

# %%
## showing top 5 records
bike_share.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
bike_share.shape
# Out:
# (730, 16)

# %%
bike_share.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
bike_share.info()
## no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
## convert 'season'  in string categorical values

def season_map(x):
    return x.map({1:'spring',2:'summer',3:'fall',4:'winter'})

bike_share[['season']]=bike_share[['season']].apply(season_map)

# %%
## counting no of records based on seasons
bike_share['season'].value_counts()
# Out:
# season
# fall      188
# summer    184
# spring    180
# winter    178
# Name: count, dtype: int64

# %%
## convert 'weathersit' in string categorical values
def weathersit_map(x):
    return x.map({1:'clear',2:'mistCloud',3:'lightRain',4:'heavyRain'})
bike_share['weathersit']=bike_share[['weathersit']].apply(weathersit_map)

# %%
## counting no of records based on weathersit
bike_share['weathersit'].value_counts()
# Out:
# weathersit
# clear        463
# mistCloud    246
# lightRain     21
# Name: count, dtype: int64

# %%
## removing repeated and unwanted column
#instant = we can remove index
#dteday=already we have yr and month so we can remove
#casual & registered =we have total count we can remove casual and & registered one to avoid collinearity
bike_share_new=bike_share[['season', 'yr', 'mnth', 'holiday', 'weekday',
       'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed','cnt']]

# %%
# Convert season,weathersit,mnth,weekday to 'category' data type

bike_share_new['season']=bike_share_new['season'].astype('category')
bike_share_new['weathersit']=bike_share_new['weathersit'].astype('category')
bike_share_new['mnth']=bike_share_new['mnth'].astype('category')
bike_share_new['weekday']=bike_share_new['weekday'].astype('category')

# %%
bike_share_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    category
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    category
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    category
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    category
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: category(4), float64(4), int64(4)
# memory usage: 49.7 KB

# %%
bike_share_new.describe()
# Out:
#                yr     holiday  workingday        temp       atemp         hum  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.500000    0.028767    0.683562   20.319259   23.726322   62.765175
# std      0.500343    0.167266    0.465405    7.506729    8.150308   14.237589
# min      0.000000    0.000000    0.000000    2.424346    3.953480    0.000000
# 25%      0.000000    0.000000    0.000000   13.811885   16.889713   52.000000
# 50%      0.500000    0.000000    1.000000   20.465826   24.368225   62.625000
# 75%      1.000000    0.000000    1.000000   26.880615   30.445775   72.989575
# max      1.000000    1.000000    1.000000   35.328347   42.044800   97.250000
#
#         windspeed          cnt
# count  730.000000   730.000000
# mean    12.763620  4508.006849
# std      5.195841  1936.011647
# min      1.500244    22.000000
# 25%      9.041650  3169.750000
# 50%     12.125325  4548.500000
# 75%     15.625589  5966.000000
# max     34.000021  8714.000000

# %%
## visualising the data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## visualising numeric values
sns.pairplot(bike_share_new[['cnt','yr','temp','atemp','hum','windspeed']],diag_kind='kde')
plt.show()

# %%
## from above pair plot its clear there is linear relationship between cnt,temp and atemp

# %%
bike_share_new
# Out:
#      season  yr mnth  holiday weekday  workingday weathersit       temp  \
# 0    spring   0    1        0       6           0  mistCloud  14.110847
# 1    spring   0    1        0       0           0  mistCloud  14.902598
# 2    spring   0    1        0       1           1      clear   8.050924
# 3    spring   0    1        0       2           1      clear   8.200000
# 4    spring   0    1        0       3           1      clear   9.305237
# ..      ...  ..  ...      ...     ...         ...        ...        ...
# 725  spring   1   12        0       4           1  mistCloud  10.420847
# 726  spring   1   12        0       5           1  mistCloud  10.386653
# 727  spring   1   12        0       6           0  mistCloud  10.386653
# 728  spring   1   12        0       0           0      clear  10.489153
# 729  spring   1   12        0       1           1  mistCloud   8.849153
#
#         atemp      hum  windspeed   cnt
# 0    18.18125  80.5833  10.749882   985
# 1    17.68695  69.6087  16.652113   801
# 2     9.47025  43.7273  16.636703  1349
# 3    10.60610  59.0435  10.739832  1562
# 4    11.46350  43.6957  12.522300  1600
# ..        ...      ...        ...   ...
# 725  11.33210  65.2917  23.458911  2114
# 726  12.75230  59.0000  10.416557  3095
# 727  12.12000  75.2917   8.333661  1341
# 728  11.58500  48.3333  23.500518  1796
# 729  11.17435  57.7500  10.374682  2729
#
# [730 rows x 12 columns]

# %%
##visualising categorical variables

plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x ='season',y ='cnt', data = bike_share_new)
plt.subplot(2,3,2)
sns.boxplot(x = 'weathersit', y = 'cnt', data = bike_share_new)
plt.subplot(2,3,3)
sns.boxplot(x = 'mnth', y = 'cnt', data = bike_share_new)
plt.subplot(2,3,4)
sns.boxplot(x = 'weekday', y = 'cnt', data = bike_share_new)
plt.subplot(2,3,5)
sns.boxplot(x = 'holiday', y = 'cnt', data = bike_share_new)
plt.subplot(2,3,6)
sns.boxplot(x = 'workingday', y = 'cnt', data = bike_share_new)
plt.show()
sns.boxplot(x = 'holiday', y = 'cnt', data = bike_share_new)
plt.subplot(2,3,6)
sns.boxplot(x = 'yr', y = 'cnt', data = bike_share_new)
plt.show()

# %%
# 1) Create Dummy variable
# 2) Drop original variable for which the dummy was created
# 3) Drop first dummy variable for each set of dummies created.

bike_share_new = pd.get_dummies(bike_share_new, drop_first=True)
bike_share_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   yr                    730 non-null    int64
#  1   holiday               730 non-null    int64
#  2   workingday            730 non-null    int64
#  3   temp                  730 non-null    float64
#  4   atemp                 730 non-null    float64
#  5   hum                   730 non-null    float64
#  6   windspeed             730 non-null    float64
#  7   cnt                   730 non-null    int64
#  8   season_spring         730 non-null    bool
#  9   season_summer         730 non-null    bool
#  10  season_winter         730 non-null    bool
#  11  mnth_2                730 non-null    bool
#  12  mnth_3                730 non-null    bool
#  13  mnth_4                730 non-null    bool
#  14  mnth_5                730 non-null    bool
#  15  mnth_6                730 non-null    bool
#  16  mnth_7                730 non-null    bool
#  17  mnth_8                730 non-null    bool
#  18  mnth_9                730 non-null    bool
#  19  mnth_10               730 non-null    bool
#  20  mnth_11               730 non-null    bool
#  21  mnth_12               730 non-null    bool
#  22  weekday_1             730 non-null    bool
#  23  weekday_2             730 non-null    bool
#  24  weekday_3             730 non-null    bool
#  25  weekday_4             730 non-null    bool
#  26  weekday_5             730 non-null    bool
#  27  weekday_6             730 non-null    bool
#  28  weathersit_lightRain  730 non-null    bool
#  29  weathersit_mistCloud  730 non-null    bool
# dtypes: bool(22), float64(4), int64(4)
# memory usage: 61.4 KB

# %%
bike_share_new.shape
# Out:
# (730, 30)

# %%
bike_share_new.head()
# Out:
#    yr  holiday  workingday       temp     atemp      hum  windspeed   cnt  \
# 0   0        0           0  14.110847  18.18125  80.5833  10.749882   985
# 1   0        0           0  14.902598  17.68695  69.6087  16.652113   801
# 2   0        0           1   8.050924   9.47025  43.7273  16.636703  1349
# 3   0        0           1   8.200000  10.60610  59.0435  10.739832  1562
# 4   0        0           1   9.305237  11.46350  43.6957  12.522300  1600
#
#    season_spring  season_summer  ...  mnth_11  mnth_12  weekday_1  weekday_2  \
# 0           True          False  ...    False    False      False      False
# 1           True          False  ...    False    False      False      False
# 2           True          False  ...    False    False       True      False
# 3           True          False  ...    False    False      False       True
# 4           True          False  ...    False    False      False      False
#
#    weekday_3  weekday_4  weekday_5  weekday_6  weathersit_lightRain  \
# 0      False      False      False       True                 False
# 1      False      False      False      False                 False
# 2      False      False      False      False                 False
# 3      False      False      False      False                 False
# 4       True      False      False      False                 False
#
#    weathersit_mistCloud
# 0                  True
# 1                  True
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 30 columns]

# %%
### split the data into train and test
from sklearn.model_selection import train_test_split
np.random.seed(0)
df_train, df_test = train_test_split(bike_share_new, train_size = 0.7, test_size = 0.3, random_state = 333)

# %%
df_train.shape
# Out:
# (510, 30)

# %%
df_test.shape
# Out:
# (219, 30)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
## rescaling the features using Min - Max

num_vars = ['temp', 'atemp', 'hum', 'windspeed', 'cnt']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

df_train.head()
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 483   1        0           0  0.497426  0.487055  0.609956   0.194850
# 650   1        0           0  0.416433  0.409971  0.513852   0.255118
# 212   0        0           1  0.887856  0.819376  0.572294   0.276919
# 714   1        0           0  0.378013  0.381804  0.871429   0.161523
# 8     0        0           0  0.098690  0.048706  0.451083   0.700017
#
#           cnt  season_spring  season_summer  ...  mnth_11  mnth_12  weekday_1  \
# 483  0.722734          False           True  ...    False    False      False
# 650  0.815347          False          False  ...    False    False      False
# 212  0.488265          False          False  ...    False    False       True
# 714  0.433042          False          False  ...    False     True      False
# 8    0.092039           True          False  ...    False    False      False
#
#      weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  \
# 483      False      False      False      False      False
# 650      False      False      False      False       True
# 212      False      False      False      False      False
# 714      False      False      False      False      False
# 8        False      False      False      False      False
#
#      weathersit_lightRain  weathersit_mistCloud
# 483                 False                 False
# 650                 False                 False
# 212                 False                 False
# 714                 False                  True
# 8                   False                 False
#
# [5 rows x 30 columns]

# %%
df_train.describe()
# Out:
#                yr     holiday  workingday        temp       atemp         hum  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.501961    0.023529    0.682353    0.540901    0.515631    0.647390
# std      0.500487    0.151726    0.466018    0.227898    0.213626    0.149722
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.343228    0.335807    0.536147
# 50%      1.000000    0.000000    1.000000    0.540519    0.525578    0.646367
# 75%      1.000000    0.000000    1.000000    0.740406    0.692378    0.757900
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         windspeed         cnt
# count  510.000000  510.000000
# mean     0.346318    0.515144
# std      0.160266    0.224281
# min      0.000000    0.000000
# 25%      0.230784    0.359468
# 50%      0.325635    0.516337
# 75%      0.434287    0.685861
# max      1.000000    1.000000

# %%
# Let's check the correlation coefficients to see which variables are highly correlated

plt.figure(figsize = (25, 15))
sns.heatmap(df_train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
### Dividing into x and y set for model building
y_train = df_train.pop('cnt')
X_train = df_train

# %%
print(y_train.shape)
print(X_train.shape)
# Out:
# (510,)
# (510, 29)

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 15
lm = LinearRegression()
lm.fit(X_train, y_train)

#rfe = RFE(lm, 15)  # running RFE
rfe = RFE(estimator=lm,n_features_to_select=15)
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('yr', True, 1),
#  ('holiday', False, 14),
#  ('workingday', True, 1),
#  ('temp', True, 1),
#  ('atemp', True, 1),
#  ('hum', True, 1),
#  ('windspeed', True, 1),
#  ('season_spring', True, 1),
#  ('season_summer', False, 7),
#  ('season_winter', True, 1),
#  ('mnth_2', False, 6),
#  ('mnth_3', True, 1),
#  ('mnth_4', False, 2),
#  ('mnth_5', True, 1),
#  ('mnth_6', False, 3),
#  ('mnth_7', False, 15),
#  ('mnth_8', False, 5),
#  ('mnth_9', True, 1),
#  ('mnth_10', True, 1),
#  ('mnth_11', False, 8),
#  ('mnth_12', False, 9),
#  ('weekday_1', False, 4),
#  ('weekday_2', False, 13),
#  ('weekday_3', False, 11),
#  ('weekday_4', False, 12),
#  ('weekday_5', False, 10),
#  ('weekday_6', True, 1),
#  ('weathersit_lightRain', True, 1),
#  ('weathersit_mistCloud', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['yr', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'season_spring', 'season_winter', 'mnth_3', 'mnth_5', 'mnth_9',
#        'mnth_10', 'weekday_6', 'weathersit_lightRain', 'weathersit_mistCloud'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['holiday', 'season_summer', 'mnth_2', 'mnth_4', 'mnth_6', 'mnth_7',
#        'mnth_8', 'mnth_11', 'mnth_12', 'weekday_1', 'weekday_2', 'weekday_3',
#        'weekday_4', 'weekday_5'],
#       dtype='object')

# %%
## creating X_train dataframe with rfe columns
X_train_rfe = X_train[col]

# %%
X_train_rfe = X_train_rfe.astype(float)
y_train = y_train.astype(float)

# %%
##Building a linear model using stats model
import statsmodels.api as sm

# Add a constant
X_train_lm1 = sm.add_constant(X_train_rfe)

# Create a first fitted model
lr1 = sm.OLS(y_train, X_train_lm1).fit()

# %%
# Check the parameters obtained

lr1.params
# Out:
# const                   0.325036
# yr                      0.229064
# workingday              0.041285
# temp                    0.325528
# atemp                   0.120080
# hum                    -0.184270
# windspeed              -0.172259
# season_spring          -0.119929
# season_winter           0.043576
# mnth_3                  0.057258
# mnth_5                  0.047588
# mnth_9                  0.092506
# mnth_10                 0.059264
# weekday_6               0.054283
# weathersit_lightRain   -0.269195
# weathersit_mistCloud   -0.045603
# dtype: float64

# %%
# Print a summary of the linear regression model obtained
print(lr1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.841
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     173.8
# Date:                Wed, 29 May 2024   Prob (F-statistic):          5.90e-186
# Time:                        00:54:02   Log-Likelihood:                 507.67
# No. Observations:                 510   AIC:                            -983.3
# Df Residuals:                     494   BIC:                            -915.6
# Df Model:                          15
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.3250      0.034      9.553      0.000       0.258       0.392
# yr                       0.2291      0.008     27.972      0.000       0.213       0.245
# workingday               0.0413      0.011      3.738      0.000       0.020       0.063
# temp                     0.3255      0.129      2.524      0.012       0.072       0.579
# atemp                    0.1201      0.136      0.884      0.377      -0.147       0.387
# hum                     -0.1843      0.038     -4.874      0.000      -0.259      -0.110
# windspeed               -0.1723      0.028     -6.191      0.000      -0.227      -0.118
# season_spring           -0.1199      0.016     -7.669      0.000      -0.151      -0.089
# season_winter            0.0436      0.015      2.886      0.004       0.014       0.073
# mnth_3                   0.0573      0.016      3.601      0.000       0.026       0.088
# mnth_5                   0.0476      0.015      3.131      0.002       0.018       0.077
# mnth_9                   0.0925      0.016      5.953      0.000       0.062       0.123
# mnth_10                  0.0593      0.018      3.316      0.001       0.024       0.094
# weekday_6                0.0543      0.014      3.783      0.000       0.026       0.082
# weathersit_lightRain    -0.2692      0.029     -9.421      0.000      -0.325      -0.213
# weathersit_mistCloud    -0.0456      0.011     -4.260      0.000      -0.067      -0.025
# ==============================================================================
# Omnibus:                       98.673   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              261.826
# Skew:                          -0.953   Prob(JB):                     1.40e-57
# Kurtosis:                       5.948   Cond. No.                         82.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features     VIF
# 2                   temp  353.18
# 3                  atemp  352.99
# 4                    hum   23.69
# 5              windspeed    5.11
# 1             workingday    4.75
# 7          season_winter    2.92
# 6          season_spring    2.91
# 14  weathersit_mistCloud    2.25
# 0                     yr    2.05
# 12             weekday_6    1.82
# 11               mnth_10    1.64
# 9                 mnth_5    1.31
# 10                mnth_9    1.22
# 13  weathersit_lightRain    1.22
# 8                 mnth_3    1.21

# %%
## removing variable atemp as its have high p-value and  high VIF

X_train_new = X_train_rfe.drop(["atemp"], axis = 1)

# %%
# Add a constant
X_train_lm2 = sm.add_constant(X_train_new)

# Create a first fitted model
lr2 = sm.OLS(y_train, X_train_lm2).fit()

# %%
# Check the parameters obtained

lr2.params
# Out:
# const                   0.327207
# yr                      0.229057
# workingday              0.041261
# temp                    0.436551
# hum                    -0.182761
# windspeed              -0.176481
# season_spring          -0.120035
# season_winter           0.044444
# mnth_3                  0.057927
# mnth_5                  0.048396
# mnth_9                  0.091994
# mnth_10                 0.059598
# weekday_6               0.054420
# weathersit_lightRain   -0.270089
# weathersit_mistCloud   -0.045883
# dtype: float64

# %%
print(lr2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     186.3
# Date:                Wed, 29 May 2024   Prob (F-statistic):          6.26e-187
# Time:                        00:54:03   Log-Likelihood:                 507.27
# No. Observations:                 510   AIC:                            -984.5
# Df Residuals:                     495   BIC:                            -921.0
# Df Model:                          14
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.3272      0.034      9.644      0.000       0.261       0.394
# yr                       0.2291      0.008     27.977      0.000       0.213       0.245
# workingday               0.0413      0.011      3.736      0.000       0.020       0.063
# temp                     0.4366      0.029     14.839      0.000       0.379       0.494
# hum                     -0.1828      0.038     -4.840      0.000      -0.257      -0.109
# windspeed               -0.1765      0.027     -6.439      0.000      -0.230      -0.123
# season_spring           -0.1200      0.016     -7.678      0.000      -0.151      -0.089
# season_winter            0.0444      0.015      2.950      0.003       0.015       0.074
# mnth_3                   0.0579      0.016      3.648      0.000       0.027       0.089
# mnth_5                   0.0484      0.015      3.190      0.002       0.019       0.078
# mnth_9                   0.0920      0.016      5.926      0.000       0.061       0.122
# mnth_10                  0.0596      0.018      3.336      0.001       0.024       0.095
# weekday_6                0.0544      0.014      3.794      0.000       0.026       0.083
# weathersit_lightRain    -0.2701      0.029     -9.460      0.000      -0.326      -0.214
# weathersit_mistCloud    -0.0459      0.011     -4.289      0.000      -0.067      -0.025
# ==============================================================================
# Omnibus:                       97.571   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              258.528
# Skew:                          -0.943   Prob(JB):                     7.27e-57
# Kurtosis:                       5.934   Cond. No.                         21.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#ViF check
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features    VIF
# 3                    hum  23.37
# 2                   temp  13.72
# 4              windspeed   4.99
# 1             workingday   4.74
# 5          season_spring   2.90
# 6          season_winter   2.89
# 13  weathersit_mistCloud   2.25
# 0                     yr   2.05
# 11             weekday_6   1.82
# 10               mnth_10   1.64
# 8                 mnth_5   1.31
# 9                 mnth_9   1.22
# 12  weathersit_lightRain   1.22
# 7                 mnth_3   1.21

# %%
## M3 Removing hum as have hight VIF
X_train_new = X_train_new.drop(["hum"], axis = 1)

# %%
# Add a constant
X_train_lm3 = sm.add_constant(X_train_new)

# Create a first fitted model
lr3 = sm.OLS(y_train, X_train_lm3).fit()

# %%
lr3.params
# Out:
# const                   0.223442
# yr                      0.233530
# workingday              0.042806
# temp                    0.410550
# windspeed              -0.139415
# season_spring          -0.124484
# season_winter           0.034843
# mnth_3                  0.064059
# mnth_5                  0.035479
# mnth_9                  0.083540
# mnth_10                 0.057595
# weekday_6               0.055082
# weathersit_lightRain   -0.324503
# weathersit_mistCloud   -0.076190
# dtype: float64

# %%
print(lr3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     190.2
# Date:                Wed, 29 May 2024   Prob (F-statistic):          3.94e-183
# Time:                        00:54:04   Log-Likelihood:                 495.48
# No. Observations:                 510   AIC:                            -963.0
# Df Residuals:                     496   BIC:                            -903.7
# Df Model:                          13
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.2234      0.027      8.311      0.000       0.171       0.276
# yr                       0.2335      0.008     28.079      0.000       0.217       0.250
# workingday               0.0428      0.011      3.793      0.000       0.021       0.065
# temp                     0.4105      0.030     13.883      0.000       0.352       0.469
# windspeed               -0.1394      0.027     -5.182      0.000      -0.192      -0.087
# season_spring           -0.1245      0.016     -7.802      0.000      -0.156      -0.093
# season_winter            0.0348      0.015      2.282      0.023       0.005       0.065
# mnth_3                   0.0641      0.016      3.959      0.000       0.032       0.096
# mnth_5                   0.0355      0.015      2.324      0.021       0.005       0.065
# mnth_9                   0.0835      0.016      5.297      0.000       0.053       0.115
# mnth_10                  0.0576      0.018      3.154      0.002       0.022       0.093
# weekday_6                0.0551      0.015      3.756      0.000       0.026       0.084
# weathersit_lightRain    -0.3245      0.027    -12.095      0.000      -0.377      -0.272
# weathersit_mistCloud    -0.0762      0.009     -8.592      0.000      -0.094      -0.059
# ==============================================================================
# Omnibus:                       92.808   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              236.797
# Skew:                          -0.912   Prob(JB):                     3.80e-52
# Kurtosis:                       5.796   Cond. No.                         16.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#ViF check
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features   VIF
# 2                   temp  6.00
# 3              windspeed  4.97
# 1             workingday  4.56
# 5          season_winter  2.12
# 4          season_spring  2.09
# 0                     yr  2.04
# 10             weekday_6  1.76
# 9                mnth_10  1.63
# 12  weathersit_mistCloud  1.54
# 7                 mnth_5  1.23
# 6                 mnth_3  1.21
# 8                 mnth_9  1.21
# 11  weathersit_lightRain  1.08

# %%
## Model 4 removing season_winter as its have high p-value

X_train_new = X_train_new.drop(["season_winter"], axis = 1)

# %%
# Add a constant
X_train_lm4 = sm.add_constant(X_train_new)

# Create a first fitted model
lr4 = sm.OLS(y_train, X_train_lm4).fit()

# %%
# Check the parameters obtained

lr4.params
# Out:
# const                   0.260437
# yr                      0.235607
# workingday              0.042102
# temp                    0.370448
# windspeed              -0.147022
# season_spring          -0.145719
# mnth_3                  0.060300
# mnth_5                  0.027806
# mnth_9                  0.086350
# mnth_10                 0.078706
# weekday_6               0.053357
# weathersit_lightRain   -0.326074
# weathersit_mistCloud   -0.076919
# dtype: float64

# %%
print(lr4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.827
# Method:                 Least Squares   F-statistic:                     203.9
# Date:                Wed, 29 May 2024   Prob (F-statistic):          3.56e-183
# Time:                        00:54:05   Log-Likelihood:                 492.81
# No. Observations:                 510   AIC:                            -959.6
# Df Residuals:                     497   BIC:                            -904.6
# Df Model:                          12
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.2604      0.022     12.092      0.000       0.218       0.303
# yr                       0.2356      0.008     28.380      0.000       0.219       0.252
# workingday               0.0421      0.011      3.716      0.000       0.020       0.064
# temp                     0.3704      0.024     15.509      0.000       0.324       0.417
# windspeed               -0.1470      0.027     -5.484      0.000      -0.200      -0.094
# season_spring           -0.1457      0.013    -11.194      0.000      -0.171      -0.120
# mnth_3                   0.0603      0.016      3.730      0.000       0.029       0.092
# mnth_5                   0.0278      0.015      1.859      0.064      -0.002       0.057
# mnth_9                   0.0864      0.016      5.469      0.000       0.055       0.117
# mnth_10                  0.0787      0.016      4.978      0.000       0.048       0.110
# weekday_6                0.0534      0.015      3.628      0.000       0.024       0.082
# weathersit_lightRain    -0.3261      0.027    -12.106      0.000      -0.379      -0.273
# weathersit_mistCloud    -0.0769      0.009     -8.643      0.000      -0.094      -0.059
# ==============================================================================
# Omnibus:                       90.597   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              225.306
# Skew:                          -0.900   Prob(JB):                     1.19e-49
# Kurtosis:                       5.713   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#ViF check
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features   VIF
# 2                   temp  5.71
# 3              windspeed  4.75
# 1             workingday  4.31
# 0                     yr  1.97
# 4          season_spring  1.89
# 9              weekday_6  1.72
# 11  weathersit_mistCloud  1.53
# 5                 mnth_3  1.20
# 6                 mnth_5  1.20
# 7                 mnth_9  1.20
# 8                mnth_10  1.16
# 10  weathersit_lightRain  1.08

# %%
## Model 5 removing mnth_5 as its have high p-value
X_train_new = X_train_new.drop(["mnth_5"], axis = 1)

# %%
# Add a constant
X_train_lm5 = sm.add_constant(X_train_new)

# Create a first fitted model
lr5 = sm.OLS(y_train, X_train_lm5).fit()

# %%
lr5.params
# Out:
# const                   0.263269
# yr                      0.235293
# workingday              0.041759
# temp                    0.374182
# windspeed              -0.148726
# season_spring          -0.148536
# mnth_3                  0.058651
# mnth_9                  0.081526
# mnth_10                 0.074424
# weekday_6               0.052909
# weathersit_lightRain   -0.327160
# weathersit_mistCloud   -0.075815
# dtype: float64

# %%
print(lr5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     221.0
# Date:                Wed, 29 May 2024   Prob (F-statistic):          1.30e-183
# Time:                        00:54:07   Log-Likelihood:                 491.05
# No. Observations:                 510   AIC:                            -958.1
# Df Residuals:                     498   BIC:                            -907.3
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.2633      0.022     12.224      0.000       0.221       0.306
# yr                       0.2353      0.008     28.278      0.000       0.219       0.252
# workingday               0.0418      0.011      3.678      0.000       0.019       0.064
# temp                     0.3742      0.024     15.682      0.000       0.327       0.421
# windspeed               -0.1487      0.027     -5.537      0.000      -0.201      -0.096
# season_spring           -0.1485      0.013    -11.461      0.000      -0.174      -0.123
# mnth_3                   0.0587      0.016      3.625      0.000       0.027       0.090
# mnth_9                   0.0815      0.016      5.222      0.000       0.051       0.112
# mnth_10                  0.0744      0.016      4.746      0.000       0.044       0.105
# weekday_6                0.0529      0.015      3.589      0.000       0.024       0.082
# weathersit_lightRain    -0.3272      0.027    -12.120      0.000      -0.380      -0.274
# weathersit_mistCloud    -0.0758      0.009     -8.517      0.000      -0.093      -0.058
# ==============================================================================
# Omnibus:                       88.184   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              211.801
# Skew:                          -0.890   Prob(JB):                     1.02e-46
# Kurtosis:                       5.608   Cond. No.                         12.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#ViF check
vif = pd.DataFrame()
vif['Features'] = X_train_new.columns
vif['VIF'] = [variance_inflation_factor(X_train_new.values, i) for i in range(X_train_new.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features   VIF
# 2                   temp  5.50
# 3              windspeed  4.75
# 1             workingday  4.31
# 0                     yr  1.97
# 4          season_spring  1.88
# 8              weekday_6  1.72
# 10  weathersit_mistCloud  1.52
# 5                 mnth_3  1.20
# 6                 mnth_9  1.17
# 7                mnth_10  1.14
# 9   weathersit_lightRain  1.08

# %%
## this looks good model as minimum p-values 
## here not removing temp as temp looks one of significant feature in bike sharing

# %%
## Residual Analysis tests
##So, now to check if the error terms are also normally distributed (which is infact, one of the major assumptions of linear regression), let us plot the histogram of the error terms and see what it looks like.

y_train_pred = lr5.predict(X_train_lm5)
res = y_train-y_train_pred
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((res), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %%
##From the above histogram, we could see that the Residuals are normally distributed. Hence our assumption for Linear Regression is valid.

# %%
## Making prediction using final Model
## Apply scaling to test set
num_vars = ['temp', 'atemp', 'hum', 'windspeed', 'cnt']
df_test[num_vars] = scaler.transform(df_test[num_vars])
df_test.head()
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 22    0        0           0  0.046591  0.025950  0.453529   0.462217
# 468   1        0           0  0.543115  0.536771  0.522511   0.347424
# 553   1        0           0  0.951196  0.933712  0.596104   0.212829
# 504   1        0           0  0.699909  0.662746  0.551083   0.478229
# 353   0        0           1  0.407087  0.416610  0.618615   0.080770
#
#           cnt  season_spring  season_summer  ...  mnth_11  mnth_12  weekday_1  \
# 22   0.110907           True          False  ...    False    False      False
# 468  0.855729          False           True  ...    False    False      False
# 553  0.534975          False          False  ...    False    False      False
# 504  0.817648          False           True  ...    False    False      False
# 353  0.428900          False          False  ...    False     True      False
#
#      weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  \
# 22       False      False      False      False      False
# 468      False      False      False      False       True
# 553      False      False      False      False      False
# 504      False      False      False      False      False
# 353       True      False      False      False      False
#
#      weathersit_lightRain  weathersit_mistCloud
# 22                  False                 False
# 468                 False                 False
# 553                 False                 False
# 504                 False                 False
# 353                 False                  True
#
# [5 rows x 30 columns]

# %%
df_test.describe()
# Out:
#                yr     holiday  workingday        temp       atemp         hum  \
# count  219.000000  219.000000  219.000000  219.000000  219.000000  219.000000
# mean     0.493151    0.041096    0.684932    0.551225    0.527528    0.662567
# std      0.501098    0.198967    0.465607    0.229463    0.215434    0.143562
# min      0.000000    0.000000    0.000000    0.046591    0.025950    0.301299
# 25%      0.000000    0.000000    0.000000    0.356479    0.348019    0.553031
# 50%      0.000000    0.000000    1.000000    0.557653    0.549198    0.662338
# 75%      1.000000    0.000000    1.000000    0.751309    0.709163    0.762338
# max      1.000000    1.000000    1.000000    0.984424    0.980934    1.010390
#
#         windspeed         cnt
# count  219.000000  219.000000
# mean     0.346706    0.518889
# std      0.159553    0.219953
# min      0.073090    0.055683
# 25%      0.232689    0.364703
# 50%      0.328208    0.525771
# 75%      0.435708    0.676887
# max      0.824380    0.963300

# %%
##Dividing into X_test and y_test
y_test = df_test.pop('cnt')
X_test = df_test
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219 entries, 22 to 313
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   yr                    219 non-null    int64
#  1   holiday               219 non-null    int64
#  2   workingday            219 non-null    int64
#  3   temp                  219 non-null    float64
#  4   atemp                 219 non-null    float64
#  5   hum                   219 non-null    float64
#  6   windspeed             219 non-null    float64
#  7   season_spring         219 non-null    bool
#  8   season_summer         219 non-null    bool
#  9   season_winter         219 non-null    bool
#  10  mnth_2                219 non-null    bool
#  11  mnth_3                219 non-null    bool
#  12  mnth_4                219 non-null    bool
#  13  mnth_5                219 non-null    bool
#  14  mnth_6                219 non-null    bool
#  15  mnth_7                219 non-null    bool
#  16  mnth_8                219 non-null    bool
#  17  mnth_9                219 non-null    bool
#  18  mnth_10               219 non-null    bool
#  19  mnth_11               219 non-null    bool
#  20  mnth_12               219 non-null    bool
#  21  weekday_1             219 non-null    bool
#  22  weekday_2             219 non-null    bool
#  23  weekday_3             219 non-null    bool
#  24  weekday_4             219 non-null    bool
#  25  weekday_5             219 non-null    bool
#  26  weekday_6             219 non-null    bool
#  27  weathersit_lightRain  219 non-null    bool
#  28  weathersit_mistCloud  219 non-null    bool
# dtypes: bool(22), float64(4), int64(3)
# memory usage: 18.4 KB

# %%
#Selecting the variables that were part of final model.
col1=X_train_new.columns
X_test=X_test[col1]
# Adding constant variable to test dataframe
X_test_lm5 = sm.add_constant(X_test)
X_test_lm5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219 entries, 22 to 313
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   const                 219 non-null    float64
#  1   yr                    219 non-null    int64
#  2   workingday            219 non-null    int64
#  3   temp                  219 non-null    float64
#  4   windspeed             219 non-null    float64
#  5   season_spring         219 non-null    bool
#  6   mnth_3                219 non-null    bool
#  7   mnth_9                219 non-null    bool
#  8   mnth_10               219 non-null    bool
#  9   weekday_6             219 non-null    bool
#  10  weathersit_lightRain  219 non-null    bool
#  11  weathersit_mistCloud  219 non-null    bool
# dtypes: bool(7), float64(3), int64(2)
# memory usage: 11.8 KB

# %%
# Making predictions using the final model (lr5)

y_pred = lr5.predict(X_test_lm5)

# %%
## Model evaluations
# Plotting y_test and y_pred to understand the spread

fig = plt.figure()
plt.scatter(y_test, y_pred, alpha=.5)
fig.suptitle('y_test vs y_pred', fontsize = 20)             
plt.xlabel('y_test', fontsize = 18)                         
plt.ylabel('y_pred', fontsize = 16) 
plt.show()

# %%
## eauation for best fitted line
cnt=0.263269+(workingday*0.041759)+(temp*0.374182)-(windspeed*0.148726)-(season_spring*0.148536)+(0.058651*mnth_3)
(mnth_9*0.081526)+(mnth_10*0.074424)+(weekday_6*0.052909)-(weathersit_lightRain*0.327160)-(weathersit_mistCloud*0.075815)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[123], line 2
#       1 ## eauation for best fitted line
# ----> 2 cnt=0.263269+(workingday*0.041759)+(temp*0.374182)-(windspeed*0.148726)-(season_spring*0.148536)+(0.058651*mnth_3)
#       3 (mnth_9*0.081526)+(mnth_10*0.074424)+(weekday_6*0.052909)-(weathersit_lightRain*0.327160)-(weathersit_mistCloud*0.075815)
#
# NameError: name 'workingday' is not defined

# %%
## eauation for best fitted line
cnt=0.263269+(yr*0.235293)+(workingday*0.041759)+(temp*0.374182)-(windspeed*0.148726)-(season_spring*0.148536)+(0.058651*mnth_3)
(mnth_9*0.081526)+(mnth_10*0.074424)+(weekday_6*0.052909)-(weathersit_lightRain*0.327160)-(weathersit_mistCloud*0.075815)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[121], line 2
#       1 ## eauation for best fitted line
# ----> 2 cnt=0.263269+(yr*0.235293)+(workingday*0.041759)+(temp*0.374182)-(windspeed*0.148726)-(season_spring*0.148536)+(0.058651*mnth_3)
#       3 (mnth_9*0.081526)+(mnth_10*0.074424)+(weekday_6*0.052909)-(weathersit_lightRain*0.327160)-(weathersit_mistCloud*0.075815)
#
# NameError: name 'yr' is not defined

# %%
# rsquare value test
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8267896869312239
